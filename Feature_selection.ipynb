# %% [markdown]
# **Задание**
#
# **Цель:**
#
# Изучить методы отбора признаков для эффективного обучения моделей машинного обучения.
#
# **Описание задания:**
#
# Решить задачу классификации точек наиболее эффективно. Для этого в работе необходимо применить различные методы по отбору признаков. Отбор признаков предпочтительнее осуществлять основываясь на математическом аппарате, поэтому данные для этого задания будут сгенерированы, чтобы избежать признаков с физическим смыслом.
#
# **Этапы работы:**
#
# 1. Сгенерируйте данные с помощью кода:
# from sklearn.datasets import make_classification
# x_data_generated, y_data_generated = make_classification(scale=1)
#
# 2. Постройте модель логистической регрессии и оцените среднюю точность. Для этого используйте следующий код:
# cross_val_score(LogisticRegression(), x, y, scoring=‘accuracy’).mean()
#
# 3. Используйте статистические методы для отбора признаков:
#
#   a) Выберите признаки на основе матрицы корреляции.
#
#   b) Отсеките низковариативные признаки (VarianceThreshold).
#
#   c) Повторите п. 2 на отобранных признаках в п. 3a, п. 3b.
#
# 4. Осуществите отбор признаков на основе дисперсионного анализа:
#
#   a) Выберите 5 лучших признаков с помощью скоринговой функции для классификации f_classif (SelectKBest(f_classif, k=5)).
#
#   b) Повторите п. 2 на отобранных признаках.
#
# 5. Отбор с использованием моделей:
#
#   a) Реализуйте отбор признаков с помощью логистической регрессии. Отобранные признаки подайте далее на вход в саму логистическую регрессию (SelectFromModel). Используйте L1 регуляризацию.
#
#   b) Реализуйте отбор признаков с помощью модели RandomForest и встроенного атрибута feature_impotance.
#
#   c) Повторите п. 2 на отобранных признаках в п. 5a, п. 5b.
#
# 6. Перебор признаков:
#
#   a) SequentialFeatureSelector.
#
#   b) Повторите п. 2 на отобранных признаках.
#
# 7. Сформулируйте выводы по проделанной работе:
#   a) Сделайте таблицу вида |способ выбора признаков|количество признаков|средняя точность модели|.

# %% [markdown]
# **1. Сгенерируйте данные с помощью кода:**
#
# `from sklearn.datasets import make_classification`
#
# `x_data_generated, y_data_generated = make_classification(scale=1)`

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import make_classification

# %%
x_data_generated, y_data_generated = make_classification(scale=1, random_state=9)

# %%
x_data_generated.shape, y_data_generated.shape
# Out:
# ((100, 20), (100,))

# %% [markdown]
# **2. Постройте модель логистической регрессии и оцените среднюю точность. Для этого используйте следующий код:**
#
# `cross_val_score(LogisticRegression(), x, y, scoring=‘accuracy’).mean()`

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_logreg = LogisticRegression()

# %%
model_logreg.fit(x_data_generated, y_data_generated)
# Out:
# LogisticRegression()

# %%
from sklearn.model_selection import cross_val_score

# %%
cvs_all = cross_val_score(model_logreg, x_data_generated, y_data_generated, scoring='accuracy').mean()
cvs_all
# Out:
# 0.86

# %% [markdown]
# **3. Используйте статистические методы для отбора признаков:**
#
#   **a) Выберите признаки на основе матрицы корреляции.**

# %%
df_x = pd.DataFrame(x_data_generated)
df_y = pd.DataFrame({'target':y_data_generated})

# %%
df = df_x.join(df_y)
df[:2]
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.061000 -0.868975  0.043621 -2.757511 -1.304449  0.074567 -1.990860
# 1 -1.058712 -1.282205  0.167144  0.144471 -0.861473  0.158882  1.756368
#
#           7         8         9  ...        11        12        13        14  \
# 0 -1.336837 -0.486052  0.954555  ...  0.769176  1.529572  0.338366 -2.621578
# 1 -1.897736 -0.651007  0.337486  ...  0.915471 -1.796172  1.798489 -0.541945
#
#          15        16        17        18        19  target
# 0  1.159243  0.956275 -0.437646  0.347415  0.476281       1
# 1  0.236401 -0.176654 -0.503043 -1.063231 -0.854900       1
#
# [2 rows x 21 columns]

# %%
corr_matrix = df.corr()
corr_matrix.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_4b859_row0_col0, #T_4b859_row1_col1, #T_4b859_row2_col2, #T_4b859_row3_col3, #T_4b859_row4_col4, #T_4b859_row5_col5, #T_4b859_row6_col6, #T_4b859_row7_col7, #T_4b859_row8_col8, #T_4b859_row9_col9, #T_4b859_row10_col10, #T_4b859_row11_col11, #T_4b859_row12_col12, #T_4b859_row13_col13, #T_4b859_row14_col14, #T_4b859_row15_col15, #T_4b859_row16_col16, #T_4b859_row17_col17, #T_4b859_row18_col18, #T_4b859_row19_col19, #T_4b859_row20_col20 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4b859_row0_col1, #T_4b859_row1_col10, #T_4b859_row5_col7, #T_4b859_row5_col8, #T_4b859_row7_col0, #T_4b859_row8_col5, #T_4b859_row9_col1, #T_4b859_row10_col1, #T_4b859_row12_col6, #T_4b859_row17_col12, #T_4b859_row18_col2, #T_4b859_row19_col6, #T_4b859_row20_col8 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_4b859_row0_col2, #T_4b859_row9_col5, #T_4b859_row14_col19, #T_4b859_row20_col15 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_4b859_row0_col3, #T_4b859_row15_col18 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_4b859_row0_col4, #T_4b859_row0_col14, #T_4b859_row3_col12, #T_4b859_row4_col1, #T_4b859_row12_col2, #T_4b859_row12_col19, #T_4b859_row13_col10, #T_4b859_row19_col9 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_4b859_row0_col5, #T_4b859_row2_col12, #T_4b859_row3_col16, #T_4b859_row8_col0, #T_4b859_row8_col6, #T_4b859_row13_col8, #T_4b859_row13_col14, #T_4b859_row15_col14, #T_4b859_row18_col4, #T_4b859_row18_col14, #T_4b859_row19_col8 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_4b859_row0_col6, #T_4b859_row5_col10, #T_4b859_row7_col8, #T_4b859_row10_col5, #T_4b859_row10_col6, #T_4b859_row19_col15 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_4b859_row0_col7, #T_4b859_row2_col1, #T_4b859_row6_col0, #T_4b859_row7_col9, #T_4b859_row18_col9 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_4b859_row0_col8, #T_4b859_row11_col14, #T_4b859_row12_col1, #T_4b859_row15_col8 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_4b859_row0_col9 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_4b859_row0_col10, #T_4b859_row8_col7, #T_4b859_row17_col13, #T_4b859_row18_col7 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_4b859_row0_col11, #T_4b859_row3_col11 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_4b859_row0_col12, #T_4b859_row3_col9, #T_4b859_row17_col9 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_4b859_row0_col13, #T_4b859_row5_col13 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_4b859_row0_col15, #T_4b859_row7_col14, #T_4b859_row11_col19, #T_4b859_row13_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_4b859_row0_col16, #T_4b859_row0_col19, #T_4b859_row6_col15, #T_4b859_row16_col19, #T_4b859_row19_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_4b859_row0_col17, #T_4b859_row3_col17, #T_4b859_row15_col13, #T_4b859_row17_col18 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_4b859_row0_col18 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_4b859_row0_col20, #T_4b859_row18_col17 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_4b859_row1_col0, #T_4b859_row2_col8, #T_4b859_row6_col19, #T_4b859_row9_col8, #T_4b859_row19_col7 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_4b859_row1_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_4b859_row1_col3, #T_4b859_row9_col3, #T_4b859_row20_col0 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_4b859_row1_col4, #T_4b859_row1_col14, #T_4b859_row3_col7, #T_4b859_row15_col9 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_4b859_row1_col5, #T_4b859_row2_col6, #T_4b859_row4_col9, #T_4b859_row5_col1, #T_4b859_row6_col2, #T_4b859_row7_col15, #T_4b859_row8_col10, #T_4b859_row9_col4, #T_4b859_row10_col0, #T_4b859_row10_col8, #T_4b859_row10_col19, #T_4b859_row11_col17, #T_4b859_row13_col18, #T_4b859_row14_col12, #T_4b859_row14_col16, #T_4b859_row15_col7, #T_4b859_row16_col14, #T_4b859_row17_col11, #T_4b859_row17_col20, #T_4b859_row18_col3, #T_4b859_row18_col13 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4b859_row1_col6, #T_4b859_row1_col7, #T_4b859_row1_col19, #T_4b859_row6_col12, #T_4b859_row13_col17, #T_4b859_row17_col10 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_4b859_row1_col8, #T_4b859_row8_col1, #T_4b859_row9_col18 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_4b859_row1_col9, #T_4b859_row13_col6, #T_4b859_row20_col6 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_4b859_row1_col11, #T_4b859_row5_col17, #T_4b859_row19_col20 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_4b859_row1_col12, #T_4b859_row3_col2, #T_4b859_row6_col10, #T_4b859_row7_col10, #T_4b859_row20_col16 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_4b859_row1_col13 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_4b859_row1_col15, #T_4b859_row3_col14, #T_4b859_row6_col9, #T_4b859_row10_col14 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_4b859_row1_col16, #T_4b859_row2_col3, #T_4b859_row11_col3 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_4b859_row1_col17, #T_4b859_row5_col11 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_4b859_row1_col18, #T_4b859_row14_col17 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_4b859_row1_col20 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_4b859_row2_col0, #T_4b859_row2_col15, #T_4b859_row4_col12, #T_4b859_row15_col2, #T_4b859_row16_col0, #T_4b859_row18_col15 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_4b859_row2_col4, #T_4b859_row6_col16, #T_4b859_row17_col15, #T_4b859_row19_col16, #T_4b859_row20_col3 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_4b859_row2_col5, #T_4b859_row7_col4, #T_4b859_row11_col8, #T_4b859_row12_col5, #T_4b859_row14_col0, #T_4b859_row14_col9, #T_4b859_row15_col10, #T_4b859_row17_col3, #T_4b859_row19_col3 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_4b859_row2_col7, #T_4b859_row2_col16, #T_4b859_row4_col0, #T_4b859_row4_col19, #T_4b859_row7_col2, #T_4b859_row16_col6, #T_4b859_row18_col6 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_4b859_row2_col9, #T_4b859_row11_col0, #T_4b859_row13_col0, #T_4b859_row14_col3, #T_4b859_row14_col6 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_4b859_row2_col10 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_4b859_row2_col11, #T_4b859_row6_col13, #T_4b859_row6_col20, #T_4b859_row8_col11 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_4b859_row2_col13, #T_4b859_row3_col20, #T_4b859_row7_col20 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_4b859_row2_col14, #T_4b859_row5_col14, #T_4b859_row6_col8, #T_4b859_row8_col3, #T_4b859_row20_col14 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_4b859_row2_col17, #T_4b859_row8_col17 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_4b859_row2_col18, #T_4b859_row18_col11, #T_4b859_row19_col13 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_4b859_row2_col19, #T_4b859_row18_col19 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_4b859_row2_col20 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_4b859_row3_col0 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_4b859_row3_col1, #T_4b859_row4_col16, #T_4b859_row15_col5, #T_4b859_row16_col8 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_4b859_row3_col4, #T_4b859_row10_col3 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_4b859_row3_col5, #T_4b859_row3_col19, #T_4b859_row5_col6, #T_4b859_row14_col7 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_4b859_row3_col6, #T_4b859_row7_col5, #T_4b859_row9_col16, #T_4b859_row13_col9, #T_4b859_row16_col10 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_4b859_row3_col8, #T_4b859_row4_col5, #T_4b859_row13_col4, #T_4b859_row13_col5, #T_4b859_row14_col8, #T_4b859_row19_col4 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_4b859_row3_col10, #T_4b859_row8_col4, #T_4b859_row20_col5 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_4b859_row3_col13 {
#   background-color: #58a1cf;
#   color: #f1

# %% [markdown]
# Согласно матрице корреляции, уберем признаки, модуль коэффициента корреляции которых меньше 0,1.

# %%
# Отсеивание наименее значимых признаков:
df_1 = df.loc[:, [0, 1, 5, 10, 11, 13, 15, 17]]
df_1.head()
# Out:
#           0         1         5        10        11        13        15  \
# 0 -0.061000 -0.868975  0.074567 -0.839500  0.769176  0.338366  1.159243
# 1 -1.058712 -1.282205  0.158882 -0.196260  0.915471  1.798489  0.236401
# 2  1.101442 -1.398838  1.336861 -1.526132  1.100319  1.818105  0.430021
# 3  0.267982  0.357477  0.319371  0.725890  0.219119  2.415371 -0.622297
# 4 -0.621145  0.470908  0.121555  2.216421  0.075988  1.226548  1.754514
#
#          17
# 0 -0.437646
# 1 -0.503043
# 2 -0.609006
# 3 -0.095031
# 4 -0.027984

# %%
# Датасет с признаками и серия с таргетом:
X_1 = df_1
y_1 = df.target

# %% [markdown]
#   **b) Отсеките низковариативные признаки (VarianceThreshold).**

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
selector_VTh = VarianceThreshold(threshold=0.5)
X_VTh = pd.DataFrame(selector_VTh.fit_transform(X_1))
X_VTh[:3]
# Out:
#           0         1         2         3         4         5         6
# 0 -0.061000 -0.868975  0.074567 -0.839500  0.769176  0.338366  1.159243
# 1 -1.058712 -1.282205  0.158882 -0.196260  0.915471  1.798489  0.236401
# 2  1.101442 -1.398838  1.336861 -1.526132  1.100319  1.818105  0.430021

# %% [markdown]
# В результате отбора осталось 7 признаков.

# %% [markdown]
#   **c) Повторите п. 2 на отобранных признаках в п. 3a, п. 3b.**

# %%
model_logreg_1 = LogisticRegression()
model_logreg_1.fit(X_VTh, y_1)
cvs_stat = cross_val_score(model_logreg_1, X_VTh, y_1, scoring='accuracy').mean()
cvs_stat
# Out:
# 0.89

# %% [markdown]
# **4. Осуществите отбор признаков на основе дисперсионного анализа:**
#
#   **a) Выберите 5 лучших признаков с помощью скоринговой функции для классификации f_classif (SelectKBest(f_classif, k=5)).**

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

# %%
selector_KB = SelectKBest(f_classif, k=5)
X_KB = pd.DataFrame(selector_KB.fit_transform(x_data_generated, y_data_generated))
X_KB[:3]
# Out:
#           0         1         2         3         4
# 0 -0.061000 -0.839500  0.769176  0.338366 -0.437646
# 1 -1.058712 -0.196260  0.915471  1.798489 -0.503043
# 2  1.101442 -1.526132  1.100319  1.818105 -0.609006

# %% [markdown]
#   **b) Повторите п. 2 на отобранных признаках.**

# %%
model_logreg_2 = LogisticRegression()
model_logreg_2.fit(X_KB, y_1)
cvs_disp = cross_val_score(model_logreg_2, X_KB, y_1, scoring='accuracy').mean()
cvs_disp
# Out:
# 0.89

# %% [markdown]
# **5. Отбор с использованием моделей:**
#
#   **a) Реализуйте отбор признаков с помощью логистической регрессии. Отобранные признаки подайте далее на вход в саму логистическую регрессию (SelectFromModel). Используйте L1 регуляризацию.**

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

# %%
# Отбор 5-ти признаков с момощью логистической регрессии и L1-регуляризации:
model_logreg_L1 = LogisticRegression(penalty='l1', solver='liblinear')
selector_SfM = SelectFromModel(model_logreg_L1, max_features=5)
X_SfM = pd.DataFrame(selector_SfM.fit_transform(x_data_generated, y_data_generated))
X_SfM[:3]
# Out:
#           0         1         2         3         4
# 0 -1.304449 -0.839500  0.769176  1.159243  0.956275
# 1 -0.861473 -0.196260  0.915471  0.236401 -0.176654
# 2  1.249654 -1.526132  1.100319  0.430021  0.341622

# %% [markdown]
#   **b) Реализуйте отбор признаков с помощью модели RandomForest и встроенного атрибута feature_impotance.**

# %%
model_RF = RandomForestClassifier(random_state=9)
model_RF.fit(x_data_generated, y_data_generated)
model_RF.feature_importances_
# Out:
# array([0.02491007, 0.0102149 , 0.02059889, 0.01576246, 0.03008207,
#        0.01936536, 0.01624872, 0.01891423, 0.01824837, 0.01544424,
#        0.0196246 , 0.27070662, 0.01300673, 0.11890757, 0.01900475,
#        0.02260322, 0.01654068, 0.27567346, 0.0312303 , 0.02291276])

# %% [markdown]
# Добавим номера признаков в соответствии с именами колонок исходного датафрейма (df_x) и отсортируем их по степени важности.

# %%
importance = pd.Series(model_RF.feature_importances_,index=df_x.columns).sort_values(ascending=False)
importance
# Out:
# 17    0.275673
# 11    0.270707
# 13    0.118908
# 18    0.031230
# 4     0.030082
# 0     0.024910
# 19    0.022913
# 15    0.022603
# 2     0.020599
# 10    0.019625
# 5     0.019365
# 14    0.019005
# 7     0.018914
# 8     0.018248
# 16    0.016541
# 6     0.016249
# 3     0.015762
# 9     0.015444
# 12    0.013007
# 1     0.010215
# dtype: float64

# %% [markdown]
# Оставим топ-3 первых по важности признака.

# %% [markdown]
#   **c) Повторите п. 2 на отобранных признаках в п. 5a, п. 5b.**

# %%
# Модель лог.регрессии и ее метрика для п. 5,а):
model_logreg.fit(X_SfM, y_data_generated)
cvs_SfM = cross_val_score(model_logreg, X_SfM, y_data_generated, scoring='accuracy').mean()
cvs_SfM
# Out:
# 0.9099999999999999

# %%
# Модель лог.регрессии и ее метрика для п. 5,b):
model_logreg.fit(df_x.loc[:, [7, 11, 13]], y_data_generated )
csv_RF = cross_val_score(model_logreg, df_x.loc[:, [7, 11, 13]], y_data_generated, scoring='accuracy').mean()
csv_RF
# Out:
# 0.89

# %% [markdown]
# **6. Перебор признаков:**
#
#   **a) SequentialFeatureSelector.**

# %%
from sklearn.feature_selection import SequentialFeatureSelector

# %%
sfs = SequentialFeatureSelector(RandomForestClassifier(random_state=9), n_features_to_select=6, direction='forward')
sfs.fit(df_x, y_data_generated)
# Out:
# SequentialFeatureSelector(estimator=RandomForestClassifier(random_state=9),
#                           n_features_to_select=6)

# %%
X_SFS = sfs.transform(df_x)
X_SFS.shape
# Out:
# (100, 6)

# %% [markdown]
# **b) Повторите п. 2 на отобранных признаках.**

# %%
model_logreg.fit(X_SFS, y_data_generated)
csv_sfs = cross_val_score(model_logreg, X_SFS, y_data_generated, scoring='accuracy').mean()
csv_sfs
# Out:
# 0.8799999999999999

# %% [markdown]
# **7. Сформулируйте выводы по проделанной работе:**
#
#   **a) Сделайте таблицу вида |способ выбора признаков|количество признаков|средняя точность модели|.**

# %%
pd.DataFrame({'Способ выбора признаков':['До выбора', 'Стат. методы', 'Дисперсионный анализ', 'SelectFromModel+L1', 'RandomForest+feature_impotance', 'SequentialFeatureSelector'],
             'Количество признаков':[x_data_generated.shape[1], X_VTh.shape[1], X_KB.shape[1], X_SfM.shape[1], 3, X_SFS.shape[1]],
              'Средняя точность модели': [cvs_all, cvs_stat, cvs_disp, cvs_SfM, csv_RF, csv_sfs]})
# Out:
#           Способ выбора признаков  Количество признаков  \
# 0                       До выбора                    20
# 1                    Стат. методы                     7
# 2            Дисперсионный анализ                     5
# 3              SelectFromModel+L1                     5
# 4  RandomForest+feature_impotance                     3
# 5       SequentialFeatureSelector                     6
#
#    Средняя точность модели
# 0                     0.86
# 1                     0.89
# 2                     0.89
# 3                     0.91
# 4                     0.89
# 5                     0.88

# %% [markdown]
# До отбора признаков модель обладала самой низкой метрикой качества, все испробованные в работе методы позволили на несколько процентов улучшить метрику, убрав при этом больше половины признаков, что эффектно демонстрирует важность процедуры отбора признаков.
